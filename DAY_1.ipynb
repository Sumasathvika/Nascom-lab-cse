# %% [markdown]
# input and output operations

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: suma
# suma

# %%
print("Hello World")
print(25)
print("Python Programming")
# Out:
# Hello World
# 25
# Python Programming

# %%
name = "Anjali"
marks = 95

print("Student Name: {name}")
print("Marks: {marks}")
# Out:
# Student Name: {name}
# Marks: {marks}

# %%
name = "Anjali"
marks = 95

print("Student Name: {}".format(name))
print("Marks: {}".format(marks))
# Out:
# Student Name: Anjali
# Marks: 95

# %%
name = "Anjali"
marks = 95

print("Student Name: %s" % name)
print("Marks: %d" % marks)
# Out:
# Student Name: Anjali
# Marks: 95

# %% [markdown]
# Topic: Input, Output and Formatted Output
# Instructions
#
#  Write the output for each program.
#  Do not execute the code.
#  If the program contains an error, write Error.
# Q1. Write the output.
# print("Welcome to Python")
# Output: _____________Welcome to Python___________________
#
# Q2. Write the output.
# print(25)
# print(50)
# Output: ___________________________25
# 50_____
#
# Q3. Write the output.
# name = "Rahul"
# print(name)
# Output: _______________________Rahul_________
#
# Q4. Write the output.
# a = 15
# b = 10
# print()
# Output: ___15
# 10__________________________
#
# Q5. Write the output.
# a = 20
# b = 4
# print()
# print()
# Output: ________20
# 4______________________
#
# Q6. Write the output.
# a = 20
# b = 3
#
# print ()
# Output: __________20
# 3
#
# ______________________
#
# Q7. Write the output.
# name = "Anjali"
# age = 19
#
# Output: _______________Anjali
# 19_________________
#
# Q8. Write the output with f string
# name = "Priya"
#
# Output: _______Priya_________________________
#
# Q9. Write the output with formar
# city = "Hyderabad"
#
# Output: __________Hyderabad______________________
#
# Q10. Write the output % formar
# name = "Kiran"
#
# Output: ___________Kiran_____________________
#
# Q11. Write the output.
# a = 5
# b = 4
#
# Output: ________________5
# 4________________
#
# Q12. Write the output.
# x = 2
# print()
# Output: __________2______________________
#
# Q13. Write the output.
# num = 25
# print()
# Output: _____________25___________________
#
# Q14. Write the float output with with 2 precision values
# value = 15.522222
# print(type(value))
# Output: ______________15.52__________________
#
# Q15. Write the output with f string
# name = "Asha"
# marks = 92
#
# Output: __________Asha
# 92______________________
#
# Q16. Write the output.
# print("Python", "Programming", "Language")
# Output: ____________Python Programming Language____________________
#
# Q17. Write the output.
# a = 10
# b = 20
# print("Sum = ", a + b)
# Output: _________________10
# 20_______________
#
# Q18. Write the output.
# name = "Rahul"
# print(name * 3)
# Output: ________________RahulRahulRahul________________
#
# Q19. Write the output.
# age = input("Enter Age: ")
#
# Output: _________________Enter Age:19_______________
#
# Q20. Write the output with fstring
# x = 10
# y = 20
#
# Output: ____________10
# 20____________________
#
# Q21. Write the output.
# name = "Amit"
# cgpa = 8.75
#
# Output: ___________Amit
# 8.75_____________________

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print(25)
print(50)
# Out:
# 25
# 50

# %%
name = "Rahul"
print(name)
# Out:
# Rahul

# %%
a = 15
b = 10
print(f"{a}")
print(f"{b}")
# Out:
# 15
# 10

# %%
a = 20
b = 4
print("%d" %a)
print("%d" %b)
# Out:
# 20
# 4

# %%
a = 20
b = 3

print ("{}".format(a))
print("{}".format(b))
# Out:
# 20
# 3

# %%
name = "Anjali"
age = 19
print(f"{name}")
print(f"{age}")
# Out:
# Anjali
# 19

# %%
name = "Priya"
print(f"{name}")
# Out:
# Priya

# %%
city = "Hyderabad"
print("{}".format(city))
# Out:
# Hyderabad

# %%
name = "Kiran"
print("%s"%name)
# Out:
# Kiran

# %%
a = 5
b = 4
print(f"{a}")
print(f"{b}")
# Out:
# 5
# 4

# %%
x = 2
print(f"{x}")
# Out:
# 2

# %%
num = 25
print(f"{num}")
# Out:
# 25

# %%
value = 15.522222
print("%.2f"%value)
# Out:
# 15.52

# %%
name = "Asha"
marks = 92
print(f"{name}")
print(f"{marks}")
# Out:
# Asha
# 92

# %%
print("Python", "Programming", "Language")
# Out:
# Python Programming Language

# %%
a = 10
b = 20
print("Sum = ", a + b)
# Out:
# Sum =  30

# %%
name = "Rahul"
print(name * 3)
# Out:
# RahulRahulRahul

# %%
age = input("Enter Age: ")
print(age)
# Out:
# Enter Age: 19
# 19

# %%
x = 10
y = 20
print(f"{x}")
print(f"{y}")
# Out:
# 10
# 20

# %%
name = "Amit"
cgpa = 8.75
print(name)
print(cgpa)
# Out:
# Amit
# 8.75

# %% [markdown]
# Functions in Python

# %%
def greet():
    print("Hello! Welcome to Python Functions.")

greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()
greet_user("Ravi")
# Out:
# Welcome, Guest!
# Welcome, Ravi!

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %%
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16

# %% [markdown]
# Lists,sets,Tuples,Dictionaries

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)


print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
fruits.append('orange')
print("After appending:", fruits)
# Out:
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
fruits.remove('banana')
print("After removing banana:", fruits)

print("Number of fruits:", len(fruits))
# Out:
# After removing banana: ['apple', 'cherry', 'apple', 'orange']
# Number of fruits: 4

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
print("Second element:", dimensions[1])
# Out:
# Second element: 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}

# %%
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
# Out:
# After adding 4: {1, 2, 3, 4}

# %%
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
# Out:
# After removing 2: {1, 3, 4}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'course': 'Python'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Alice

# %%
student['grade'] = 'A'
print("After adding grade:", student)


del student['age']
print("After deleting age:", student)

for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}

# %% [markdown]
# Indexing and Slicing

# %%
my_list = [10, 20, 30, 40, 50]

# %%
print("First element:", my_list[0])
print("Last element:", my_list[-1])
# Out:
# First element: 10
# Last element: 50

# %%
print("Elements from index 1 to 3 (not inclusive):", my_list[1:4])
print("From start to index 2:", my_list[:3])
print("From index 2 to end:", my_list[2:])
print("Every second element:", my_list[::2])
print("Reversed list:", my_list[::-1])
# Out:
# Elements from index 1 to 3 (not inclusive): [20, 30, 40]
# From start to index 2: [10, 20, 30]
# From index 2 to end: [30, 40, 50]
# Every second element: [10, 30, 50]
# Reversed list: [50, 40, 30, 20, 10]
